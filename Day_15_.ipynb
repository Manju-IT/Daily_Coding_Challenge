# %%
# import pandas as pd 
# len(pd.unique(list(str(129128282))))


# def dou(f,x):
#     return f(f(x))

# def sq(x):
#     return x*x

# dou(sq,3)

# def make_adder(n):
#     def adder(x):
#         return x+n 
#     return adder 
# # one = make_adder(4)
# # one(5)

# def sq(x):
#     return x*x
# def tri(x):
#     return 3*x
# def com(f,g):
#     def h(x):
#         return f(g(x))
#     return h 
# sqp= com(sq,tri)   ## sqp= h
# sqp(3)             ## sqp = h(3) = sq(tri(3)) = sq(3*3) = sq(9) = 81

# squadder = com(sq,make_adder(2)) 
# squadder(3)         ## squadder = h
#                     ## squadder = h(3) = sq(make_adder(2)(3)) = sq(3+2) = sq(5) = 25

# from operator import add, mul

# square = lambda x: x * x

# identity = lambda x: x

# triple = lambda x: 3 * x

# increment = lambda x: x + 1

# def product(n, term):
#     return term(n) if n==1 else  term(n) * product(n-1, term)

# # product(3, square)  

# def acc(f,s,n,t):
#     return f(t(n),s) if n==0 else acc(f,s,t(n),t)
# acc(add,11,3,square)  

# def mk(f,n):
#     def g(x):
#         for i in range(n):
#             x = f(x)
#         return x
#     return g
# mk(triple,5)(1)

# a=1
# def fun(g):
#     a=2
#     return lambda y : a*g(y) ## 2 + lambda y: 1+y
# fun(lambda y: a+y)(a)
# def end(n,d):
   
#     while n>0:
#        l,n=n%10,n//10
#        print(l)
#        if l==d:
#            return None
# end(34567,5)
# def search(f):
# 	x = 0
# 	while True:
# 	    if f(x):
# 	        return x
# 	    x += 1
# def square(x):
# 	return x * x
	
# def inverse(f):
# 	    """Return g(y) such that g(f(x)) -> x."""
# 	return lambda y: search(lambda x: f(x) == y)
# sqrt = inverse(square)
# qrt(16)
