# %%
import numpy as np 
import pandas as pd 
# import matplotlib.pyplot as plt

# %%
# a = np.array([1,2,3,4])
# print(a==4)

# a = np.array([3,4,6,10,24,89,45,43,46,99,100])
# print(a[a%3!=0])
# print(a[(a%3==0) & (a%5==0)])

## Calculate the prime numbers between 0 and 100 by using a Boolean array.

# a = np.arange(1,100)
# a[(a%2!=0) & (a%3!=0)]

# a = np.array([[100, 175, 210],
# [90, 160, 150],
# [200, 50, 100],
# [120, 0, 310]])
# b = np.array([2.98, 3.90, 1.99])
# price_incents = np.dot(a,b)
# print(price_incents/100)   # [13.984 11.907  9.9    9.745]

# a = np.array([[100, 175, 210],
# [90, 160, 150],
# [200, 50, 100],
# [120, 0, 310]])
# np.savetxt("sample.txt",a,delimiter=" ;",fmt="%.18e",newline="\n", header="ajshah",footer="jjjaksjaj",comments="jsdhsjhdsjdnsjsndjdjsh")
# x = np.loadtxt("sample.txt")
# print(x)

# %%
## MAtplot Lib

# a= np.array([1,2,2,5,3])
# plt.plot(a)
# plt.plot(a,"ob")

# a = np.arange(1,9)
# b=np.array([25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1])
# fig,ax= plt.subplots()
# plt.plot(a,b)
# ax.set(xlabel="sanms",ylabel="sahsa")

a = np.arange(1,9)
b = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
c = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]

# fig, ax= plt.subplots()
# ax.plot(a,b,
#         a,b,"oy",a,c,
#         a,c,"or")

plt.bar(a,b,color="green")
plt.plot()
plt.show() 
plt.bar(a,c,color="black")

plt.plot()
plt.show()

# %%
a = np.arange(1,9)
b = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
c = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]

plt.scatter(a,b,marker="^",color="r")
plt.scatter(a,c,marker="v",color="m")
plt.plot()
plt.show()

# %%
# fig,ax = plt.subplots()
# ax.plot(1,2)
# import scipy.misc
# face = scipy.misc.face()
# print(face.shape)
# print(face.max)
# print(face.dtype)
# plt.axis("off")
# plt.gray()
# plt.imshow(face)
# plt.show()
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# def imag_tile(img, n, m=1):

#     if n == 1:
#         tiled_img = img
#     else:
#         lst_imgs = []
#         for i in range(n):
#             lst_imgs.append(img)
#             tiled_img = np.concatenate(lst_imgs, axis=1 )
#     if m > 1:
#         lst_imgs = []
#         for i in range(m):
#             lst_imgs.append(tiled_img)
#             tiled_img = np.concatenate(lst_imgs, axis=0 )
#     return tiled_img
# basic_pattern = mpimg.imread('decorators_b2.png')
# decorators_img = imag_tile(basic_pattern, 3, 3)
# plt.axis("off")
# plt.imshow(decorators_img)

# def img_show(img,n,m):
    
#     if n==1:
#         tit_img=img
#     else:
#         lis_img=[]
#         for _ in range(n):
#             lis_img.append(lis_img)
#         tit_img=np.concatenate(lis_img,axis=1)
#     if m>1:
#         lis_img=[]
#         for _ in range(m):
#             lis_img.append(tit_img)
#         tit_img=np.concatenate(lis_img,axis=0)
#     return tit_img
# dec=mpimg.imread('decorators_b2.png')
# dec_img=img_show(dec,3,3)
    
# plt.axis("off")
# plt.imshow(dec_img)ssssss

# %%
# s= pd.Series(['snasnn',"ajhs",'sajs','sjsj'])
# a = pd.Series([21,3,4,5],index=s)
# # print(a)       
# """snasnn    21
# ajhs       3
# sajs       4
# sjsj       5
# dtype: int64"""

# a.apply(lambda x:x>4)
# """snasnn     True
# ajhs      False
# sajs      False
# sjsj       True
# dtype: bool"""
# cities = {"London": 8615246,
# "Berlin": 3562166,
# "Madrid": 3165235,
# "Rome": 2874038,
# "Paris": 2273305,
# "Vienna": 1805681,
# "Bucharest": 1803425,
# "Hamburg": 1760433,
# "Budapest": 1754000,
# "Warsaw": 1740119,
# "Barcelona": 1602386,
# "Munich": 1493900,
# "Milan": 1350680}

# # tab=pd.Series(cities)
# # print(tab)
# """London       8615246
# Berlin       3562166
# Madrid       3165235
# Rome         2874038
# Paris        2273305
# Vienna       1805681
# Bucharest    1803425
# Hamburg      1760433
# Budapest     1754000
# Warsaw       1740119
# Barcelona    1602386
# Munich       1493900
# Milan        1350680
# dtype: int64"""


# # cities2 = {"London": 8615246,
# # "Berlin": 3562166,
# # "Madrid": 3165235,
# # "Rome": 2874038,
# # "Paris": 2273305,
# # "Vienna": 1805681,
# # "Bucharest": 0,
# # "Hamburg": 1760433,
# # "Budapest": 1754000,
# # "Warsaw": 0,
# # "Barcelona": 1602386,
# # "Munich": 0,
# # "Milan": 1350680}

# # mis=pd.Series(cities2)
# # mis.dropna()

# %%
# years=np.arange(2014,2018)
# shop1 = pd.Series([2409.14, 2941.01, 3496.83, 3119.55], index=years)
# shop2 = pd.Series([1203.45, 3441.62, 3007.83, 3619.53], index=years)
# shop3 = pd.Series([3412.12, 3491.16, 3457.19, 1963.10], index=years)

# shop1.name="sjas"
# shop2.name = "sajjsh"
# shop3.name = "skaskj"
# a = pd.concat([shop1,shop2,shop3],axis=1)
# a   
"""      sjas  sajjsh	skaskj
2014	2409.14	1203.45	3412.12
2015	2941.01	3441.62	3491.16
2016	3496.83	3007.83	3457.19
2017	3119.55	3619.53	1963.10"""

cities = {"name": ["London", "Berlin", "Madrid", "Rome",
"Paris", "Vienna", "Bucharest", "Hamburg",
"Budapest", "Warsaw", "Barcelona",
"Munich", "Milan"],
"population": [8615246, 3562166, 3165235, 2874038,
2273305, 1805681, 1803425, 1760433,
1754000, 1740119, 1602386, 1493900,
1350680],
"country": ["England", "Germany", "Spain", "Italy",
"France", "Austria", "Romania",
"Germany", "Hungary", "Poland", "Spain",
"Germany", "Italy"]}

a= pd.DataFrame(cities)

"""name	population	country
0	London	8615246	England
1	Berlin	3562166	Germany
2	Madrid	3165235	Spain
3	Rome	2874038	Italy
4	Paris	2273305	France
5	Vienna	1805681	Austria
6	Bucharest	1803425	Romania
7	Hamburg	1760433	Germany
8	Budapest	1754000	Hungary
9	Warsaw	1740119	Poland
10	Barcelona	1602386	Spain
11	Munich	1493900	Germany
12	Milan	1350680	Italy"""

a.columns.values
a.columns.value_counts()
ordinals = ["first", "second", "third", "fourth",
"fifth", "sixth", "seventh", "eigth",
"ninth", "tenth", "eleventh", "twelvth",
"thirteenth"]

pd.DataFrame(cities,index=ordinals)

"""name	population	country
first	London	8615246	England
second	Berlin	3562166	Germany
third	Madrid	3165235	Spain
fourth	Rome	2874038	Italy
fifth	Paris	2273305	France
sixth	Vienna	1805681	Austria
seventh	Bucharest	1803425	Romania
eigth	Hamburg	1760433	Germany
ninth	Budapest	1754000	Hungary
tenth	Warsaw	1740119	Poland
eleventh	Barcelona	1602386	Spain
twelvth	Munich	1493900	Germany
thirteenth	Milan	1350680	Italy
"""
a.reindex(index=[0, 2, 4, 6, 8, 10, 12, 1, 3, 5, 7, 9, 1,1])

""" name	population	country
0	London	8615246	England
2	Madrid	3165235	Spain
4	Paris	2273305	France
6	Bucharest	1803425	Romania
8	Budapest	1754000	Hungary
10	Barcelona	1602386	Spain
12	Milan	1350680	Italy
1	Berlin	3562166	Germany
3	Rome	2874038	Italy
5	Vienna	1805681	Austria
7	Hamburg	1760433	Germany
9	Warsaw	1740119	Poland
1	Berlin	3562166	Germany
1	Berlin	3562166	Germany """
# print(a.loc["Paris"])
# Out:
# ' name\tpopulation\tcountry\n0\tLondon\t8615246\tEngland\n2\tMadrid\t3165235\tSpain\n4\tParis\t2273305\tFrance\n6\tBucharest\t1803425\tRomania\n8\tBudapest\t1754000\tHungary\n10\tBarcelona\t1602386\tSpain\n12\tMilan\t1350680\tItaly\n1\tBerlin\t3562166\tGermany\n3\tRome\t2874038\tItaly\n5\tVienna\t1805681\tAustria\n7\tHamburg\t1760433\tGermany\n9\tWarsaw\t1740119\tPoland\n1\tBerlin\t3562166\tGermany\n1\tBerlin\t3562166\tGermany '
